# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('data/Beacon-Hill-data-from-May2018.csv',header=1)
df
# Out:
#         Date      Time Trace SO2 Trace NO Trace NOy Trace NOy-NO WAQA_CO  \
# 0        NaN       NaN       ppb      ppb       ppb          ppb     ppm
# 1     5/1/18  12:00 AM      0.34      1.9      14.1         12.1     NaN
# 2     5/2/18  12:00 AM      0.49      6.7      22.5         15.6     NaN
# 3     5/3/18  12:00 AM      0.52      6.6      16.8         10.1     NaN
# 4     5/4/18  12:00 AM      0.33      0.8       5.6          4.7     NaN
# ..       ...       ...       ...      ...       ...          ...     ...
# 716  MaxTime       NaN     12:00    12:00     12:00        12:00   12:00
# 717      Avg       NaN      0.71      4.8      15.2         10.3   0.201
# 718      Num       NaN       662      697       697          697      37
# 719  Data[%]       NaN        93       98        98           98       5
# 720      STD       NaN       0.3      7.9        12          5.2       0
#
#         O3 BAM_PM25 NO2_CAPS
# 0      ppm   ug/m^3      ppb
# 1    0.024      NaN   14.351
# ...

# %%
df2=df[['Date','NO2_CAPS']]
df2
# Out:
#         Date NO2_CAPS
# 0        NaN      ppb
# 1     5/1/18   14.351
# 2     5/2/18   14.983
# 3     5/3/18    8.318
# 4     5/4/18    5.072
# ..       ...      ...
# 716  MaxTime    12:00
# 717      Avg   10.622
# 718      Num      701
# 719  Data[%]       98
# 720      STD      5.2
#
# [721 rows x 2 columns]

# %%
df3=df2[1:710]  #clean data
df3
# Out:
#        Date NO2_CAPS
# 1    5/1/18   14.351
# 2    5/2/18   14.983
# 3    5/3/18    8.318
# 4    5/4/18    5.072
# 5    5/5/18   10.622
# ..      ...      ...
# 705  4/4/20    4.401
# 706  4/5/20    4.253
# 707  4/6/20    7.487
# 708  4/7/20    8.462
# 709  4/8/20    9.492
#
# [709 rows x 2 columns]

# %%
df3['Date'] = pd.to_datetime(df3['Date'])
df3
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#           Date NO2_CAPS
# 1   2018-05-01   14.351
# 2   2018-05-02   14.983
# 3   2018-05-03    8.318
# 4   2018-05-04    5.072
# 5   2018-05-05   10.622
# ..         ...      ...
# 705 2020-04-04    4.401
# 706 2020-04-05    4.253
# 707 2020-04-06    7.487
# 708 2020-04-07    8.462
# 709 2020-04-08    9.492
#
# [709 rows x 2 columns]

# %%
df3['NO2_CAPS']=df3['NO2_CAPS'].astype(float)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 709 entries, 1 to 709
# Data columns (total 2 columns):
# Date        709 non-null datetime64[ns]
# NO2_CAPS    700 non-null float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 11.2 KB

# %%
df3['Day'] = df3['Date'].dt.day
df3['Month'] = df3['Date'].dt.month
df3['Year'] = df3['Date'].dt.year
df3
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
fig,ax= plt.subplots(figsize=(12,2))

ax.plot(df3['Date'],df3['NO2_CAPS'])
ax.set_ylabel('NO2 concentration (ppb)')
ax.set_xlabel('Date')
ax.set_title('NO2 concentrations versus time at Seattle Beacon Hill location')
# Out:
# Text(0.5, 1.0, 'NO2 concentrations versus time at Seattle Beacon Hill location')

# %%
df4=df3[610:]
df4
# Out:
#           Date  NO2_CAPS  Day  Month  Year
# 611 2020-01-01     2.095    1      1  2020
# 612 2020-01-02     9.839    2      1  2020
# 613 2020-01-03    15.987    3      1  2020
# 614 2020-01-04     4.755    4      1  2020
# 615 2020-01-05     5.012    5      1  2020
# ..         ...       ...  ...    ...   ...
# 705 2020-04-04     4.401    4      4  2020
# 706 2020-04-05     4.253    5      4  2020
# 707 2020-04-06     7.487    6      4  2020
# 708 2020-04-07     8.462    7      4  2020
# 709 2020-04-08     9.492    8      4  2020
#
# [99 rows x 5 columns]

# %%
fig,ax= plt.subplots(figsize=(16,8))

ax.plot(df4['Date'],df4['NO2_CAPS'])
ax.set_ylabel('NO2 concentration (ppb)')
ax.set_xlabel('Date')
ax.set_title('NO2 concentrations versus time at Seattle Beacon Hill location')
ax.axvline(pd.to_datetime('2020-03-17'),ls='--',color='red')
ax.axvline(pd.to_datetime('2020-01-21'),ls='--',color='green')
ax.axvline(pd.to_datetime('2020-03-3'),ls='--',color='purple')
ax.legend(['','WA school closures begin','first US coronavirus case confirmed in WA state','Seattle Mayor declares state of emergency'])
# Tuesday, March 17
#df4['Date']=2020-03-17
